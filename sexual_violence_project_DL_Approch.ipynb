# %%
import pandas as pd
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import string
from nltk.tokenize import RegexpTokenizer
import re
from google.colab import drive
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 
print(tf.__version__)
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
import matplotlib.pyplot as plt

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# 2.9.2
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
drive.mount('/content/gdrive')
df = pd.read_csv("/content/gdrive/MyDrive/sexual_violence_project/tweets_with_snscrape_20-22.csv", encoding='utf8')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Declarations
stopwordlist = ['a', 'about', 'above', 'after', 'again', 'ain', 'all', 'am', 'an',
             'and','any','are', 'as', 'at', 'be', 'because', 'been', 'before',
             'being', 'below', 'between','both', 'by', 'can', 'd', 'did', 'do',
             'does', 'doing', 'down', 'during', 'each','few', 'for', 'from',
             'further', 'had', 'has', 'have', 'having', 'he', 'her', 'here',
             'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 'if', 'in',
             'into','is', 'it', 'its', 'itself', 'just', 'll', 'm', 'ma',
             'me', 'more', 'most','my', 'myself', 'now', 'o', 'of', 'on', 'once',
             'only', 'or', 'other', 'our', 'ours','ourselves', 'out', 'own', 're','s', 'same', 'she', "shes", 'should', "shouldve",'so', 'some', 'such',
             't', 'than', 'that', "thatll", 'the', 'their', 'theirs', 'them',
             'themselves', 'then', 'there', 'these', 'they', 'this', 'those',
             'through', 'to', 'too','under', 'until', 'up', 've', 'very', 'was',
             'we', 'were', 'what', 'when', 'where','which','while', 'who', 'whom',
             'why', 'will', 'with', 'won', 'y', 'you', "youd","youll", "youre",
             "youve", 'your', 'yours', 'yourself', 'yourselves']

english_punctuations = string.punctuation
punctuations_list = english_punctuations

# %%
#Function Definations
def cleaning_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)
    
def cleaning_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

def cleaning_repeating_char(text):
    return re.sub(r'(.)1+', r'1', text)

def cleaning_URLs(data):
    return re.sub('((www.[^s]+)|(https?://[^s]+))',' ',data)

def cleaning_numbers(data):
    return re.sub('[0-9]+', '', data)

def stemming_on_text(data):
    text = [st.stem(word) for word in data]
    return data

def lemmatizer_on_text(data):
    text = [lm.lemmatize(word) for word in data]
    return data

def remove_https(text):
  partial_list = text.split(" ")
  ans = ""
  for ele in partial_list:
    if(ele.startswith("https")):
      pass
    else:
      ans+=ele+" "
  return ans

def HashTag_Remover(text):
  temp_list = text.split(" ")
  h_ans = ""
  for ele in temp_list:
    if(ele.startswith("#")):
      pass
    else:
      h_ans+=ele+" "
  return h_ans

def feature_extractor(text):
  Colo_Name = {0:"Fear of retaliation" , 1:"Not aware of assault", 2: "Not aware of assault", 3: "Considered assault as not serious", 4:"Didn’t want to involve others",5: "No proper action taken for accidents", 6: "Anonyms and Non-personal Tweets."}
  score_list = [0,0,0,0,0,0]
  temp_list = text.split(" ")
  for ele in temp_list:
    if F_O_I.count(ele)>0: score_list[0] += 1
    elif N_A_A.count(ele)>0: score_list[1] += 1
    elif C_A_NS.count(ele)>0: score_list[2] += 1
    elif D_W_IO.count(ele)>0: score_list[3] += 1
    elif N_P_APA.count(ele)>0: score_list[4]+=1
    else: score_list[5] += 1
  max = 0
  # print(score_list)
  for cn in score_list:
    if cn > max and cn!=score_list[5]: max = cn
  if max == 0: 
    # print("Hi")
    return Colo_Name[6]
  else: 
    # print(max)
    return Colo_Name[score_list.index(max)+1]

def feature_list(text):
  score_list = [0,0,0,0,0,0]
  temp_list = text.split(" ")
  for ele in temp_list:
    if F_O_I.count(ele)>0: score_list[0] += 1
    elif N_A_A.count(ele)>0: score_list[1] += 1
    elif C_A_NS.count(ele)>0: score_list[2] += 1
    elif D_W_IO.count(ele)>0: score_list[3] += 1
    elif N_P_APA.count(ele)>0: score_list[4]+=1
    else: score_list[5] += 1
  return score_list

# %%
df.head()
# Out:
#    Unnamed: 0                       Date             User  \
# 0           0  2022-10-26 14:05:29+00:00     zeroffenders
# 1           1  2022-10-26 12:27:55+00:00     zeroffenders
# 2           2  2022-10-05 20:47:10+00:00      bottyrubble
# 3           3  2022-10-01 14:55:08+00:00  AmybeTravelling
# 4           4  2022-09-29 21:45:18+00:00     zeroffenders
#
#                                                Tweet
# 0  https://t.co/dXgUDi5fTc\n\nA dentist was charg...
# 1  VIOLADOR:\nCristian Villalobos \nOrtodoncista ...
# 2                                   #whyididntreport
# 3  @MacFarlaneNews Their friends are trying to mu...
# 4  https://t.co/rL5hSiXonW\n\nMost of Dahmer's vi...

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
df.head()
# Out:
#                         Date             User  \
# 0  2022-10-26 14:05:29+00:00     zeroffenders
# 1  2022-10-26 12:27:55+00:00     zeroffenders
# 2  2022-10-05 20:47:10+00:00      bottyrubble
# 3  2022-10-01 14:55:08+00:00  AmybeTravelling
# 4  2022-09-29 21:45:18+00:00     zeroffenders
#
#                                                Tweet
# 0  https://t.co/dXgUDi5fTc\n\nA dentist was charg...
# 1  VIOLADOR:\nCristian Villalobos \nOrtodoncista ...
# 2                                   #whyididntreport
# 3  @MacFarlaneNews Their friends are trying to mu...
# 4  https://t.co/rL5hSiXonW\n\nMost of Dahmer's vi...

# %%
df1 = df.drop(['Date','User'],axis=1)

# %%
df1.head()
# Out:
#                                                Tweet
# 0  https://t.co/dXgUDi5fTc\n\nA dentist was charg...
# 1  VIOLADOR:\nCristian Villalobos \nOrtodoncista ...
# 2                                   #whyididntreport
# 3  @MacFarlaneNews Their friends are trying to mu...
# 4  https://t.co/rL5hSiXonW\n\nMost of Dahmer's vi...

# %%
df1['Tweet']=df1['Tweet'].str.lower()
df1['Tweet'].tail()
# Out:
# 29849    @jdesquiredr @ericahill84 #2: listen to victim...
# 29850    but rape apologists want more stories of #whyi...
# 29851    an injustice system that violates cannot be ex...
# 29852    #violenceagainstwomen\n#whyididntreport\n#beli...
# 29853    #whathappensaftermetoo #tacklingtheiceberg #me...
# Name: Tweet, dtype: object

# %%
df1.at[0,'Tweet']
# Out:
# 'https://t.co/dxgudi5ftc\n\na dentist was charged with rapes of women.\n\nfarzam mehrabi is accused of meeting women through dating apps before drugging them and sexually assaulting them.\n\n#metoo #whyididntreport #antofagasta #osorno #rapist #25n https://t.co/z7ybj76saj'

# %%
#Removing Stop Words From Tweet
STOPWORDS = set(stopwordlist)
df1['Tweet'] = df1['Tweet'].apply(lambda text: cleaning_stopwords(text))
df1['Tweet'].head()
# Out:
# 0    https://t.co/dxgudi5ftc dentist charged rapes ...
# 1    violador: cristian villalobos ortodoncista - c...
# 2                                     #whyididntreport
# 3    @macfarlanenews friends trying murder suicidal...
# 4    https://t.co/rl5hsixonw dahmer's victims kille...
# Name: Tweet, dtype: object

# %%
#Removing Link/Url From tweet
df1['Tweet'] = df1['Tweet'].apply(lambda x: cleaning_URLs(x))
df1['Tweet'].tail()
# Out:
# 29849    @jdesquiredr @ericahill84 #2: listen victims s...
# 29850    but rape apologists want stories #whyididntrep...
# 29851    injustice system violates cannot expected admi...
# 29852    #violenceagainstwomen #whyididntreport #believ...
# 29853    #whathappensaftermetoo #tacklingtheiceberg #me...
# Name: Tweet, dtype: object

# %%
#Removing Hashtags From tweet
df1['Tweet'] = df1['Tweet'].apply(lambda x: HashTag_Remover(x))
df1['Tweet'].tail()
# Out:
# 29849    @jdesquiredr @ericahill84 listen victims stori...
# 29850    but rape apologists want stories push changes ...
# 29851    injustice system violates cannot expected admi...
# 29852    | state state guide statutes limitations @rain...
# 29853                                                  se
# Name: Tweet, dtype: object

# %%
#Removing Punctuations
df1['Tweet']= df1['Tweet'].apply(lambda x: cleaning_punctuations(x))
df1['Tweet'].tail()
# Out:
# 29849    jdesquiredr ericahill84 listen victims stories...
# 29850    but rape apologists want stories push changes ...
# 29851    injustice system violates cannot expected admi...
# 29852      state state guide statutes limitations rainn
# 29853                                                  se
# Name: Tweet, dtype: object

# %%
#Removing Duplicate Charactert
df1['Tweet'] = df1['Tweet'].apply(lambda x: cleaning_repeating_char(x))
df1['Tweet'].tail()
# Out:
# 29849    jdesquiredr ericahill84 listen victims stories...
# 29850    but rape apologists want stories push changes ...
# 29851    injustice system violates cannot expected admi...
# 29852      state state guide statutes limitations rainn
# 29853                                                  se
# Name: Tweet, dtype: object

# %%
#Removing Numeric numbers from the tweets 
df1['Tweet'] = df1['Tweet'].apply(lambda x: cleaning_numbers(x))
df1['Tweet'].tail()
# Out:
# 29849    jdesquiredr ericahill listen victims stories d...
# 29850    but rape apologists want stories push changes ...
# 29851    injustice system violates cannot expected admi...
# 29852      state state guide statutes limitations rainn
# 29853                                                  se
# Name: Tweet, dtype: object

# %%
df1['Tweet']
# Out:
# 0         st charged rapes women farzam mehrabi accused...
# 1        violador cristian villalobos ortodoncista  chi...
# 2
# 3        macfarlanenews friends trying murder suicidal ...
# 4         sixonw dahmers victims killed drugged sedativ...
#                                ...
# 29849    jdesquiredr ericahill listen victims stories d...
# 29850    but rape apologists want stories push changes ...
# 29851    injustice system violates cannot expected admi...
# 29852      state state guide statutes limitations rainn
# 29853                                                  se
# Name: Tweet, Length: 29854, dtype: object

# %%
st = nltk.PorterStemmer()
df1['Tweet'] =  df1['Tweet'].apply(lambda x: stemming_on_text(x))
df1['Tweet'].head(5)
# Out:
# 0     st charged rapes women farzam mehrabi accused...
# 1    violador cristian villalobos ortodoncista  chi...
# 2
# 3    macfarlanenews friends trying murder suicidal ...
# 4     sixonw dahmers victims killed drugged sedativ...
# Name: Tweet, dtype: object

# %%
lm = nltk.WordNetLemmatizer()
df1['Tweet'] = df1['Tweet'].apply(lambda x: lemmatizer_on_text(x))
df1['Tweet'].head()
# Out:
# 0     st charged rapes women farzam mehrabi accused...
# 1    violador cristian villalobos ortodoncista  chi...
# 2
# 3    macfarlanenews friends trying murder suicidal ...
# 4     sixonw dahmers victims killed drugged sedativ...
# Name: Tweet, dtype: object

# %%
df1['Tweet'] = df1['Tweet'].apply(lambda x: remove_https(x))
df1['Tweet'].head()
# Out:
# 0     st charged rapes women farzam mehrabi accused...
# 1    violador cristian villalobos ortodoncista  chi...
# 2
# 3    macfarlanenews friends trying murder suicidal ...
# 4     sixonw dahmers victims killed drugged sedativ...
# Name: Tweet, dtype: object

# %%
df1.shape
# Out:
# (29854, 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29854 entries, 0 to 29853
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   29854 non-null  object
# dtypes: object(1)
# memory usage: 233.4+ KB

# %%
df1.describe()
# Out:
#         Tweet
# count   29854
# unique  28202
# top
# freq      759

# %%
data_pos = df1['Tweet']
wc = WordCloud(max_words = 1000 , width = 1600 , height = 800,
              collocations=False).generate(" ".join(data_pos))
plt.figure(figsize = (20,20))
plt.imshow(wc)

# %%
F_O_I = [ "bullied", "terrified", "popularity", "blackmail", "kill", "abduction", "nightmares", "revenge", "violent", "beat", "bully", "afraid", "fear", "feared", "scared"]
N_A_A = [ "ignorance", "manipulation", "harsh", "degradation", "aggressive", "illiteracy", "boyfriend", "friend", "brother", "cousin", "kid", "didn’t know", "miseducation"]
C_A_NS = [ "Fault" , "deserve", "drunk" , "naïve", "unbelief", "immoral dressing", "denial", "internalized", "victim-blaming", "attitudes", "mistake"]
D_W_IO = [ "stigmatization", "ashamed", "uncomfortable", "embarrassed", "pity", "guilty", "traumatized", "confused", "rejection", "popular"]
N_P_APA = [ "Evidence", "dilemma", "memory-loss", "tardiness", "delay","reporting", "took me seriously", "believed me"]

# %%
F_O_I_temp = "bullied, terrified, popularity, blackmail, kill, abduction, nightmares, revenge, violent, beat, bully, afraid, fear, feared, scared, know, dead, tell, abduct, strong, mean, mad, harassed, violence, threat, threatened, killed, death, pain, control, couldn, silence, destroy"
N_A_A_temp = "ignorance, manipulation, harsh, degradation, aggressive, illiteracy, boyfriend, friend, brother, cousin, kid, didn’t know, miseducation, age, didn’t, love, sister, father, young, know, realize, dad, mom, ignorant, child, molested, learned, learnt, naïve, guilt, girlfriend, partner, children, taught, play, younger, knew, trusted" 
C_A_NS_temp = "fault, deserve, drunk, immoral dressing, denial, internalized victim-blaming attitudes, mistake, deserve, blame, deserved, courage, small, drinking, immoral, serious, sexual, raped, culture, hand, leg, almost, visit, touched, house, late, often, internalized, watched, drinking, smoking, night, lost, ex, contract, self"
D_W_IO_temp = "stigmatization, ashamed, uncomfortable, embarrassed, pity, guilty, traumatized, confused, rejection, popular, secret, neighbor, member, ruin, family, reputation, image, position, kept, future, church, quiet"
N_P_APA_temp = "evidence, dilemma, memory-loss, tardiness, delay, seriously, police, reported, justice, evidence, believed, officer, liar, overreacting, overreact, court, support, understand, unbelief, valid, truth, action, true, heal, blamed, barely, listen, process"
F_O_I_temp = lm.lemmatize(F_O_I_temp)
N_A_A_temp = lm.lemmatize(N_A_A_temp)
C_A_NS_temp = lm.lemmatize(C_A_NS_temp)
D_W_IO_temp = lm.lemmatize(D_W_IO_temp)
N_P_APA_temp = lm.lemmatize(N_P_APA_temp)
F_O_I_temp = F_O_I_temp.lower().replace(" ","")
N_A_A_temp = N_A_A_temp.lower().replace(" ","")
C_A_NS_temp = C_A_NS_temp.lower().replace(" ","")
D_W_IO_temp = D_W_IO_temp.lower().replace(" ","")
N_P_APA_temp = N_P_APA_temp.lower().replace(" ","")
F_O_I = F_O_I_temp.split(",")
N_A_A = N_A_A_temp.split(",")
C_A_NS = C_A_NS_temp.split(",")
D_W_IO = D_W_IO_temp.split(",")
N_P_APA = N_P_APA_temp.split(",")

# %%
print(F_O_I)
print(N_A_A)
print(C_A_NS)
print(D_W_IO)
print(N_P_APA)
# Out:
# ['bullied', 'terrified', 'popularity', 'blackmail', 'kill', 'abduction', 'nightmares', 'revenge', 'violent', 'beat', 'bully', 'afraid', 'fear', 'feared', 'scared', 'know', 'dead', 'tell', 'abduct', 'strong', 'mean', 'mad', 'harassed', 'violence', 'threat', 'threatened', 'killed', 'death', 'pain', 'control', 'couldn', 'silence', 'destroy']
# ['ignorance', 'manipulation', 'harsh', 'degradation', 'aggressive', 'illiteracy', 'boyfriend', 'friend', 'brother', 'cousin', 'kid', 'didn’tknow', 'miseducation', 'age', 'didn’t', 'love', 'sister', 'father', 'young', 'know', 'realize', 'dad', 'mom', 'ignorant', 'child', 'molested', 'learned', 'learnt', 'naïve', 'guilt', 'girlfriend', 'partner', 'children', 'taught', 'play', 'younger', 'knew', 'trusted']
# ['fault', 'deserve', 'drunk', 'immoraldressing', 'denial', 'internalizedvictim-blamingattitudes', 'mistake', 'deserve', 'blame', 'deserved', 'courage', 'small', 'drinking', 'immoral', 'serious', 'sexual', 'raped', 'culture', 'hand', 'leg', 'almost', 'visit', 'touched', 'house', 'late', 'often', 'internalized', 'watched', 'drinking', 'smoking', 'night', 'lost', 'ex', 'contract', 'self']
# ['stigmatization', 'ashamed', 'uncomfortable', 'embarrassed', 'pity', 'guilty', 'traumatized', 'confused', 'rejection', 'popular', 'secret', 'neighbor', 'member', 'ruin', 'family', 'reputation', 'image', 'position', 'kept', 'future', 'church', 'quiet']
# ['evidence', 'dilemma', 'memory-loss', 'tardiness', 'delay', 'seriously', 'police', 'reported', 'justice', 'evidence', 'believed', 'officer', 'liar', 'overreacting', 'overreact', 'court', 'support', 'understand', 'unbelief', 'valid', 'truth', 'action', 'true', 'heal', 'blamed', 'barely', 'listen', 'process']

# %%
m = [1,2,3,4,5]
m.index(1)
# Out:
# 0

# %%
def feature_extractor(text):
  Colo_Name = {0:"Fear of retaliation" , 1:"Not aware of assault", 2: "Not aware of assault", 3: "Considered assault as not serious", 4:"Didn’t want to involve others",5: "No proper action taken for accidents", 6: "Anonyms and Non-personal Tweets."}
  score_list = [0,0,0,0,0,0]
  temp_list = text.split(" ")
  for ele in temp_list:
    if F_O_I.count(ele)>0: score_list[0] += 1
    elif N_A_A.count(ele)>0: score_list[1] += 1
    elif C_A_NS.count(ele)>0: score_list[2] += 1
    elif D_W_IO.count(ele)>0: score_list[3] += 1
    elif N_P_APA.count(ele)>0: score_list[4]+=1
    else: score_list[5] += 1
  max = 0
  for cn in score_list:
    if cn > max and cn!=score_list[5]: max = cn
  if max == 0: 
    return Colo_Name[6]
  else: 
    return Colo_Name[score_list.index(max)+1]
print(feature_extractor("I did report rape threats when I was emailed and stalked by a classmate. The police and school told me it was my problem. No one even tried to help, except my friends who became bodyguards #whyIdidntreport should be #whydonttheycare"))
# Out:
# No proper action taken for accidents

# %%
def feature_list(text):
  score_list = [0,0,0,0,0,0]
  temp_list = text.split(" ")
  for ele in temp_list:
    if F_O_I.count(ele)>0: score_list[0] += 1
    elif N_A_A.count(ele)>0: score_list[1] += 1
    elif C_A_NS.count(ele)>0: score_list[2] += 1
    elif D_W_IO.count(ele)>0: score_list[3] += 1
    elif N_P_APA.count(ele)>0: score_list[4]+=1
    else: score_list[5] += 1
  return score_list
print(feature_list("I did report rape threats when I was emailed and stalked by a classmate. The police and school told me it was my problem. No one even tried to help, except my friends who became bodyguards #whyIdidntreport should be #whydonttheycare"))
# Out:
# [0, 0, 0, 0, 1, 39]

# %%
df2['OutCome'] = df2['Tweet'].apply(lambda x: feature_extractor(x))
df2['OutCome'].value_counts()
# Out:
# Not aware of assault                    13282
# Anonyms and Non-personal Tweets.        10111
# Considered assault as not serious        2958
# No proper action taken for accidents     1932
# Didn’t want to involve others            1571
# Name: OutCome, dtype: int64

# %%
##Lists To Classify Text Into Different Classes 
"""
There Will Be Total of 5 Classes namely:- 
1. Fear of retaliation.
2. Not aware of assault.
3. Considered assault as not serious.
4. Didn’t want to involve others.
5. No proper action taken for prior accidents.
6. Anonyms and Non-personal Tweets.
"""
# Out:
# '\nThere Will Be Total of 5 Classes namely:- \n1. Fear of retaliation.\n2. Not aware of assault.\n3. Considered assault as not serious.\n4. Didn’t want to involve others.\n5. No proper action taken for prior accidents.\n6. Anonyms and Non-personal Tweets.\n'

# %%
df2['Features'] = df2['Tweet'].apply(lambda x: feature_list(x))
df2.head(5)
# Out:
#                                                Tweet  \
# 0   st charged rapes women farzam mehrabi accused...
# 1  violador cristian villalobos ortodoncista  chi...
# 2
# 3  macfarlanenews friends trying murder suicidal ...
# 4   sixonw dahmers victims killed drugged sedativ...
#
#                             OutCome             Features
# 0  Anonyms and Non-personal Tweets.  [0, 0, 0, 0, 0, 20]
# 1  Anonyms and Non-personal Tweets.  [0, 0, 0, 0, 0, 17]
# 2  Anonyms and Non-personal Tweets.   [0, 0, 0, 0, 0, 2]
# 3  Anonyms and Non-personal Tweets.  [0, 0, 0, 0, 0, 22]
# 4              Not aware of assault  [1, 0, 0, 0, 0, 18]

# %%
df3 = df2.drop('Tweet',axis=1)

# %%
df3.head()
# Out:
#                             OutCome             Features
# 0  Anonyms and Non-personal Tweets.  [0, 0, 0, 0, 0, 20]
# 1  Anonyms and Non-personal Tweets.  [0, 0, 0, 0, 0, 17]
# 2  Anonyms and Non-personal Tweets.   [0, 0, 0, 0, 0, 2]
# 3  Anonyms and Non-personal Tweets.  [0, 0, 0, 0, 0, 22]
# 4              Not aware of assault  [1, 0, 0, 0, 0, 18]

# %%
X=np.array(df3['Features'].tolist())
y=np.array(df3['OutCome'].tolist())

# %%
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))

# %%
np.unique(y)
# Out:
# array([0., 1.], dtype=float32)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (23883, 6)
# (23883, 5)
# (5971, 6)
# (5971, 5)

# %%
num_labels=y.shape[1]

# %%
num_labels
# Out:
# 5

# %%
model=Sequential()
###first layer
model.add(Dense(500,input_shape=(6,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(800))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(700))
model.add(Activation('relu'))
model.add(Dropout(0.5))

###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 500)               3500
#
#  activation_4 (Activation)   (None, 500)               0
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_5 (Dense)             (None, 800)               400800
#
#  activation_5 (Activation)   (None, 800)               0
#
#  dropout_4 (Dropout)         (None, 800)               0
#
#  dense_6 (Dense)             (None, 700)               560700
#
#  activation_6 (Activation)   (None, 700)               0
#
#  dropout_5 (Dropout)         (None, 700)               0
#
#  dense_7 (Dense)             (None, 5)                 3505
#
#  activation_7 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 968,505
# Trainable params: 968,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
num_epochs = 100
num_batch_size = 32

# checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
#                                verbose=1, save_best_only=True)
start = datetime.now()

history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 747/747 [==============================] - 11s 14ms/step - loss: 0.3420 - accuracy: 0.8940 - val_loss: 0.0318 - val_accuracy: 0.9918
# Epoch 2/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0569 - accuracy: 0.9861 - val_loss: 0.0254 - val_accuracy: 0.9963
# Epoch 3/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0435 - accuracy: 0.9898 - val_loss: 0.0328 - val_accuracy: 0.9955
# Epoch 4/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0337 - accuracy: 0.9918 - val_loss: 0.0231 - val_accuracy: 0.9990
# Epoch 5/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0380 - accuracy: 0.9912 - val_loss: 0.0179 - val_accuracy: 0.9977
# Epoch 6/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0363 - accuracy: 0.9919 - val_loss: 0.0152 - val_accuracy: 0.9990
# Epoch 7/100
# 747/747 [==============================] - 13s 17ms/step - loss: 0.0316 - accuracy: 0.9934 - val_loss: 0.0164 - val_accuracy: 0.9982
# Epoch 8/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0280 - accuracy: 0.9937 - val_loss: 0.0150 - val_accuracy: 0.9990
# Epoch 9/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0227 - accuracy: 0.9948 - val_loss: 0.0154 - val_accuracy: 0.9987
# Epoch 10/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0307 - accuracy: 0.9933 - val_loss: 0.0137 - val_accuracy: 0.9988
# Epoch 11/100
# 747/747 [==============================] - 12s 16ms/step - loss: 0.0252 - accuracy: 0.9951 - val_loss: 0.0151 - val_accuracy: 0.9985
# Epoch 12/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0278 - accuracy: 0.9945 - val_loss: 0.0149 - val_accuracy: 0.9982
# Epoch 13/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0224 - accuracy: 0.9954 - val_loss: 0.0126 - val_accuracy: 0.9988
# Epoch 14/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0268 - accuracy: 0.9944 - val_loss: 0.0169 - val_accuracy: 0.9980
# Epoch 15/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0257 - accuracy: 0.9950 - val_loss: 0.0146 - val_accuracy: 0.9990
# Epoch 16/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0257 - accuracy: 0.9951 - val_loss: 0.0112 - val_accuracy: 0.9995
# Epoch 17/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0250 - accuracy: 0.9941 - val_loss: 0.0116 - val_accuracy: 0.9990
# Epoch 18/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0218 - accuracy: 0.9946 - val_loss: 0.0137 - val_accuracy: 0.9990
# Epoch 19/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0223 - accuracy: 0.9950 - val_loss: 0.0134 - val_accuracy: 0.9988
# Epoch 20/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0199 - accuracy: 0.9959 - val_loss: 0.0081 - val_accuracy: 0.9997
# Epoch 21/100
# 747/747 [==============================] - 11s 14ms/step - loss: 0.0226 - accuracy: 0.9960 - val_loss: 0.0106 - val_accuracy: 0.9988
# Epoch 22/100
# 747/747 [==============================] - 11s 15ms/step - loss: 0.0254 - accuracy: 0.9948 - val_loss: 0.0116 - val_accuracy: 0.9990
# Epoch 23/100
# 747/747 [==============================] - 11s 15ms/step - loss: 0.0213 - accuracy: 0.9960 - val_loss: 0.0099 - val_accuracy: 0.9990
# Epoch 24/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.
100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0226 - accuracy: 0.9963 - val_loss: 0.0082 - val_accuracy: 0.9988
# Epoch 55/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0238 - accuracy: 0.9958 - val_loss: 0.0119 - val_accuracy: 0.9987
# Epoch 56/100
# 747/747 [==============================] - 11s 15ms/step - loss: 0.0211 - accuracy: 0.9962 - val_loss: 0.0091 - val_accuracy: 0.9985
# Epoch 57/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0212 - accuracy: 0.9969 - val_loss: 0.0111 - val_accuracy: 0.9988
# Epoch 58/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0209 - accuracy: 0.9963 - val_loss: 0.0134 - val_accuracy: 0.9977
# Epoch 59/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0207 - accuracy: 0.9967 - val_loss: 0.0092 - val_accuracy: 0.9990
# Epoch 60/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0209 - accuracy: 0.9964 - val_loss: 0.0129 - val_accuracy: 0.9988
# Epoch 61/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0185 - accuracy: 0.9964 - val_loss: 0.0102 - val_accuracy: 0.9985
# Epoch 62/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0197 - accuracy: 0.9964 - val_loss: 0.0081 - val_accuracy: 0.9995
# Epoch 63/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0256 - accuracy: 0.9966 - val_loss: 0.0090 - val_accuracy: 0.9988
# Epoch 64/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0213 - accuracy: 0.9961 - val_loss: 0.0119 - val_accuracy: 0.9988
# Epoch 65/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0162 - accuracy: 0.9970 - val_loss: 0.0115 - val_accuracy: 0.9995
# Epoch 66/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0178 - accuracy: 0.9972 - val_loss: 0.0114 - val_accuracy: 0.9985
# Epoch 67/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0213 - accuracy: 0.9962 - val_loss: 0.0091 - val_accuracy: 0.9995
# Epoch 68/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0183 - accuracy: 0.9973 - val_loss: 0.0080 - val_accuracy: 0.9992
# Epoch 69/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0190 - accuracy: 0.9968 - val_loss: 0.0088 - val_accuracy: 0.9990
# Epoch 70/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0227 - accuracy: 0.9967 - val_loss: 0.0085 - val_accuracy: 0.9993
# Epoch 71/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0185 - accuracy: 0.9962 - val_loss: 0.0120 - val_accuracy: 0.9990
# Epoch 72/100
# 747/747 [==============================] - 10s 13ms/step - loss: 0.0248 - accuracy: 0.9961 - val_loss: 0.0096 - val_accuracy: 0.9990
# Epoch 73/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0262 - accuracy: 0.9959 - val_loss: 0.0076 - val_accuracy: 0.9995
# Epoch 74/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.0089 - val_accuracy: 0.9987
# Epoch 75/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0182 - accuracy: 0.9970 - val_loss: 0.0077 - val_accuracy: 0.9988
# Epoch 76/100
# 747/747 [==============================] - 14s 19ms/step - loss: 0.0219 - accuracy: 0.9972 - val_loss: 0.0080 - val_accuracy: 0.9988
# Epoch 77/100
# 747/747 [==============================] - 12s 16ms/step - loss: 0.0229 - accuracy: 0.9963 - val_loss: 0.0105 - val_accuracy: 0.9993
# Epoch 78/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.0220 - accuracy: 0.9959 - val_loss: 0.0068 - val_accuracy: 0.9993
# Epoch 79/100
# 747/747 [==============================] - 11s 14ms/step - loss: 0.0224 - accuracy: 0.9964 - val_loss: 0.0064 - val_accuracy: 0.9995
# Epoch 80/100
# 747/747 [==============================] - 10s 14ms/step - loss: 0.